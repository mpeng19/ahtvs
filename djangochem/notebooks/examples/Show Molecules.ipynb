# %% [markdown]
# ## Quick Start ##
#
# This notebook will step through some cool ways to work with your molecule database
#
# One thing to note.  There are lots of ways to customize jupyter notebooks and the ipython kernel.  In this case, I am avoiding any of that awesome magic and instead I am writing out all the setup explicitly here in the notebook itself.  The only special config in the notebook_config.py file is to start the notebook in the 'notebooks' directory

# %%
import os
import sys
import django
import pprint
import pandas as pd

# setup the djhango settings file.  Change this to use the settings file that connects you to your desired database
os.environ["DJANGO_SETTINGS_MODULE"] = "djangochem.settings.docker"
# this must be run to setup access to the django settings and make database access work etc.
django.setup()

# import the models that you want to access
from pgmols.models import Mol, Calc, Geom
from jobs.models import Job, JobConfig

# this is all setup for the notebook
from IPython.display import HTML
import matplotlib
# %matplotlib inline
from rdkit.Chem import AllChem as Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools # headsup: this import change the behavior of dataframes with mols in them
# some global configuration of the pandastools
PandasTools.molRepresentation = 'svg'
PandasTools.molSize = (200,200)

# %%
# this is a little helper function to render images inside a dataframe
# once again, there are ways to monkey patch the rendering of dataframes, but I am trying to 
# avoid most of that to make things a bit easier to understand

def show(df):
    return HTML(df.to_html(escape=False))

# %% [markdown]
# Now we can have some fun

# %%
# we will pull 9 molecules from our db.  (this is assuming you've already run a test molgen)
# the to_dict method of the Mol objects gives us an rdkit Mol objects, a smiles string, and the contents of the details json
mol_dicts = [m.to_dict() for m in Mol.objects.filter(group__name__exact='test_project').all()[:9]]
mol_dicts
# Out:
# [{'electron_count': 122,
#   'generation': 1,
#   'mass': 234.09054632,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7fc2d3fce800>,
#   'molecular_charge': 0,
#   'smiles': 'c1ccc2c(c1)c1ccccc1n2-n1cnnc1',
#   'stoichiometry': 'C14H10N4',
#   'tags': ['product']},
#  {'electron_count': 122,
#   'generation': 1,
#   'mass': 234.09054632,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7fc2d89bdf30>,
#   'molecular_charge': 0,
#   'smiles': 'c1ccc2c(c1)[nH]c1ccc(-n3cnnc3)cc12',
#   'stoichiometry': 'C14H10N4',
#   'tags': ['product']},
#  {'electron_count': 36,
#   'generation': 0,
#   'mass': 69.03269709599999,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7fc2d89bde90>,
#   'molecular_charge': 0,
#   'smiles': 'c1nnc[nH]1',
#   'stoichiometry': 'C2H3N3',
#   'tags': ['fragment', 'acceptors']},
#  {'electron_count': 156,
#   'generation': 1,
#   'mass': 301.10759335200004,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7fc2d89bde40>,
#   'molecular_charge': 0,
#   'smiles': 'c1nnc(-c2ccc3[nH]c4ccc(-c5nnc[nH]5)cc4c3c2)[nH]1',
#   'stoichiometry': 'C16H11N7',
#   'tags': ['product']},
#  {'electron_count': 122,
#   'generation': 1,
#   'mass': 234.09054632,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7fc2d3ff3080>,
#   'molecular_charge': 0,
#   'smiles': 'c1ccc2c(c1)c1ccccc1n2-c1nnc[nH]1',
#   'stoichiometry': 'C14H10N4',
#   'tags': ['product']},
#  {'electron_count': 156,
#   'generation': 1,
#   'mass': 301.10759335200004,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7fc2d3ff30d0>,
#   'molecular_charge': 0,
#   'smiles': 'c1cc2[nH]c3ccc(-n4cnnc4)cc3c2cc1-n1cnnc1',
#   'stoichiometry': 'C16H11N7',
#   'tags': ['product']},
#  {'electron_count': 88,
#   'generation': 0,
#   'mass': 167.073499288,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7fc2d3ff3120>,
#   'molecular_charge': 0,
#   'smiles': 'c1ccc2c(c1)[nH]c1ccccc12',
#   'stoichiometry': 'C12H9N',
#   'tags': ['fragment', 'donor']},
#  {'electron_count': 208,
#   'generation': 1,
#   'mass': 399.14839554400004,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7fc2d3ff3170>,
#   'molecular_charge': 0,
#   'smiles': 'c1ccc2c(c1)c1ccccc1n2-c1nnc(-n2c3ccccc3c3ccccc32)[nH]1',
#   'stoichiometry': 'C26H17N5',
#   'tags': ['product']},
#  {'electron_count': 208,
#   'generation': 1,
#   'mass': 399.1483955440001,
#   'mol': <rdkit.Chem.rdchem.Mol at 0x7fc2d3ff31c0>,
#   'molecular_charge': 0,
#   'smiles': 'c1ccc2c(c1)[nH]c1ccc(-c3nnc(-c4ccc5[nH]c6ccccc6c5c4)[nH]3)cc12',
#   'stoichiometry': 'C26H17N5',
#   'tags': ['product']}]

# %%
# builtin rdkit tools to view mols
Draw.MolsToGridImage([m['mol'] for m in mol_dicts], molsPerRow=4)

# %%
# we can make a pandas dataframe directly from the list of dicts
df = pd.DataFrame(mol_dicts)
# specify the columns you want to see
cols = ['mol', 'mass', 'stoichiometry']
show(df[cols])  # show is defined at top of notebook
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mol</th>
#       <th>mass</th>
#       <th>stoichiometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><svg baseProfile="full" height="200px" version="1.1" width="200px" xml:space="preserve" xmlns:rdkit="http://www.rdkit.org/xml" xmlns:svg="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">\n<rect height="200" style="opacity:1.0;fill:#FFFFFF;stroke:none" width="200" x="0" y="0"> </rect>\n<path d="M 9.09091,100.665 20.5278,65.466" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 17.8463,97.6728 25.8521,73.0333" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;stroke-dasharray:6,6"/>\n<path d="M 9.09091,100.665 33.8559,128.17" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 18.3065,99.8379 35.642,119.091" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;stroke-dasharray:6,6"/>\n<path d="M 20.5278,65.466 56.7297,57.7711" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 27.4971,71.5522 52.8384,66.1657" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;stroke-dasharray:6,6"/>\n<path d="M 56.7297,57.7711 81.4947,85.2754" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 54.9436,66.8497 72.2791,86.1027" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;stroke-dasharray:6,6"/>\n<path d="M 81.4947,85.2754 70.0578,120.475" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 72.7393,88.2679 64.7334,112.907" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;stroke-dasharray:6,6"/>\n<path d="M 81.4947,85.2754 118.505,85.2754" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 87.0463,92.6775 112.954,92.6775" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;stroke-dasharray:6,6"/>\n<path d="M 70.0578,120.475 33.8559,128.17" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 63.0885,114.388 37.7472,119.775" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;stroke-dasharray:6,6"/>\n<path d="M 70.0578,120.475 80.7838,128.268" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 80.7838,128.268 91.5099,136.06" style="fill:none;fill-rule:evenodd;stroke:#0000FF;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 77.6264,116.824 85.1347,122.279" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;stroke-dasharray:6,6"/>\n<path d="M 85.1347,122.279 92.6429,127.734" style="fill:none;fill-rule:evenodd;stroke:#0000FF;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;stroke-dasharray:6,6"/>\n<path d="M 108.49,136.06 119.216,128.268" style="fill:none;fill-rule:evenodd;stroke:#0000FF;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 119.216,128.268 129.942,120.475" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 107.357,1 ...
#       <td>167.073499</td>
#       <td>C12H9N</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><svg baseProfile="full" height="200px" version="1.1" width="200px" xml:space="preserve" xmlns:rdkit="http://www.rdkit.org/xml" xmlns:svg="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">\n<rect height="200" style="opacity:1.0;fill:#FFFFFF;stroke:none" width="200" x="0" y="0"> </rect>\n<path d="M 190.909,100 165.705,65.3089" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 165.705,65.3089 140.5,30.6178" style="fill:none;fill-rule:evenodd;stroke:#0000FF;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1"/>\n<path d="M 165.871,102.29 148.228,78.0066" style="fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1;stroke-dasharray:6,6"/>\n<path d="M 148.228,78.0066 130.584,53.7228" style="

# %%
# and once we are in a dataframe, we get csv output for free!
csvcols = ['smiles', 'mass', 'stoichiometry']
df[csvcols].to_csv('output.csv')
